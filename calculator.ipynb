# %% [markdown]
# # AI-programming-1-a

# %% [markdown]
# ## シンプルな電卓

# %% [markdown]
# **このノートブックを使用してプロジェクトを完了する方法**
#
# 1. マークダウンセルで回答することにより、必要なすべての質問に回答する必要があります。
# 2. 指示を読み、＃todoセクションに記入します。
# 3. すべてのセルを実行して、各コードの結果を保存します。
# 4. [ファイル]をクリックしてこのノートブックを保存し、[ダウンロード]をクリックして[HTML]を選択します。
# 5. AIP_IndividualProjectという名前の新しいリポジトリを作成して、このノートブックをGitHubリポジトリにプッシュします。 提出日（2019年6月29日午後1時30分）まで、このリポジトリをプライベートとして設定します。

# %% [markdown]
# **前書き**
#
# 簡単な電卓をプログラムすることを想像してください
# 電卓の基本的な計算は、加算、減算、乗算、除算です。 計算機は整数のみの計算を行うのではなく、小数も含まれることに注意してください。

# %% [markdown]
# **質問1：**
#
# このタスクのプログラムを記述するフローチャートを作成します。 パワーポイントを使用してフローチャートを描画し、それを.jpgまたは.pngの画像として保存できます。 次に、このコマンドを使用して、下の「回答」列にアクセスします。
# `<img src=_____.jpg>`

# %% [markdown]
# **回答**:
# <br>
# <img src="1.png" height="533" width="155">
# <img src="2.png" height="533" width="694">
# <img src="3.png" height="563" width="853">

# %% [markdown]
# **ステップ1**:
#
# #TODO
#
# ユーザーに入力を求めます。 人間がコンピューターで操作したい数字を入力した時点で、プログラムの作成を開始します。 このプログラムでは、ユーザーに2つの数字とタイプを入力してもらいたいので、プログラムに2つの数字とタイプを入力してもらいましょう。

# %%
num1=input('一番目の数字を入力してください')
num2=input('二番目の数字を入力してください')
print('タイプはadd,minus,plus,divise,powerの中から一つを選んでください')
type=input('タイプを入力してください')
# Out:
# 一番目の数字を入力してください1
# 二番目の数字を入力してください2
# タイプはadd,minus,plus,divise,powerの中から一つを選んでください
# タイプを入力してくださいadd

# %% [markdown]
# **ステップ2**
#
# #TODO
#
# - calculatorのクラスを作成して、`__init__()`関数で初期化し、二つの数値とタイプを設定する
# - calculatorのクラスの中にaccumlation（）という関数を付け、関数自体にインデントのレイヤーを追加します。 関数accumlation（）は二つの数値でどちらが大きい（あるいは小さい）かどうかを判断します。
# - calculatorのクラスの中にcalculate（）という関数を付け、関数自体にインデントのレイヤーを追加します。 関数calculate（）は算術演算を定義しています。

# %%
class calculator():
  def __init__(self,num1,num2,type):
    self.num1=int(num1)
    self.num2=int(num2)
    self.type=type

  def accumlation(self):
    r=""
    sum=0
    product=1
    if self.num1>self.num2:
      r=range(self.num2,self.num1+1)
    else:
      r=range(self.num1,self.num2+1)
    if self.type=="add":
      for i in r:
        sum=sum+i
      print('累計は{}です'.format(sum))
    elif self.type=="plus":
      for i in r:
        product=product*i
      print('累積は{}です'.format(product))
    elif self.type=="minus" or self.type=="divise" or self.type=="power":
      print('累計、累積以外に計算できません')
    else:
      print('タイプが間違ています')
  
  def calculate(self):
    result=""
    if self.type=="add":
      result=self.num1+self.num2
    elif self.type=="minus":
      result=self.num1-self.num2
    elif self.type=="plus":
      result=self.num1*self.num2
    elif self.type=="divise":
      if self.num2==0:
        result="エラー"
      else:
        result=self.num1/self.num2
    elif self.type=="power":
      result=self.num1**self.num2
    else:
      print('タイプが間違ています')
    if result!="":
      print('結果は{}です'.format(result))

# %% [markdown]
# **ステップ3**
#
# #TODO
#
# - インスタンスを生成
# - メソッド呼び出し

# %%
c=calculator(num1,num2,type)
print('result:')
c.calculate()
print('accumlation:')
c.accumlation()
# Out:
# result:
# 結果は3です
# accumlation:
# 累計は3です
